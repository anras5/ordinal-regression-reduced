# %%
import numpy as np
import pandas as pd

from mcda.dataset import MCDADataset

original_data = MCDADataset.read_csv("./data/insulating-materials/dataset.csv")
df = original_data.data

covariance_matrix = df.cov()
means = df.mean()

rng = np.random.default_rng(42)
num_samples = df.shape[0]

synthetic_data = rng.multivariate_normal(mean=means, cov=covariance_matrix, size=30)

synthetic_data_df = pd.DataFrame(synthetic_data, columns=df.columns).astype(np.float64)

synthethic_dataset = MCDADataset(synthetic_data_df, original_data.criteria)
synthethic_dataset.write_csv("./data/insulating-materials/dataset30.csv")
# Out:
# /tmp/ipykernel_23/1712783945.py:15: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   synthetic_data = rng.multivariate_normal(mean=means, cov=covariance_matrix, size=30)

# %%
original_data.data
# Out:
#      global warming  ozone layer depletion  respiratory inorganics  \
# a1       -12096.012              -0.001231                 -5.5728
# a2       -15746.557              -0.000633                 -5.6160
# a3         -797.040              -0.000028                 -0.4168
# a4        -3650.403              -0.000335                 -4.0392
# a5        -1531.441              -0.000070                 -2.3328
# a6        -2332.802              -0.000397                 -1.5465
# a7         -855.360              -0.000086                 -0.9050
# a8         -630.720              -0.000074                 -0.3456
# a9        -1995.841              -0.000488                 -0.9374
# a10       -2354.402              -0.000001                 -2.7432
# a11        -788.400              -0.000096                 -1.2787
# a12        -311.040              -0.000035                 -0.4039
#
#      non-renewable energy  net present value  comfort  energy saving
# a1             -246240.24           -2951.50 -3657.79          65.67
# a2             -139537.39           -2670.14 -4392.80          59.41
# a3              -22680.02           -2980.71 -3750.48          66.32
# a4              -81216.08           -2843.18 -3974.48          63.26
# a5              -23328.02           -3001.83 -3659.44          66.79
# a6              -73008.07           -2984.31 -3681.89          66.40
# a7              -12074.41           -2975.77 -3685.51          66.21
# a8              -10821.61           -2908.35 -3921.44          64.71
# a9              -33264.03           -2853.07 -3893.64          60.76
# a10             -65880.06           -3093.07 -3357.30          68.82
# a11             -12182.41           -2730.82 -4478.60          63.48
# a12              -6177.60           -2954.19 -3800.44          65.73

# %%
synthethic_dataset.data
# Out:
#     global warming  ozone layer depletion  respiratory inorganics  \
# 0     -7499.208430              -0.000695               -2.094608
# 1     -2293.110959              -0.000211               -2.285216
# 2     -7752.785341              -0.000313               -3.985906
# 3      2406.351947              -0.000064               -0.004658
# 4     -4233.247305              -0.000612               -2.391330
# 5     -8746.780833              -0.000529               -4.436178
# 6      -144.892406              -0.000061               -1.554245
# 7     -3140.170279              -0.000227               -1.852647
# 8      1332.425759              -0.000369                0.165849
# 9     -4303.162206              -0.000518               -2.308850
# 10     -980.544973               0.000195               -0.625177
# 11    -2705.291547              -0.000390               -1.734559
# 12     2761.639460               0.000138               -0.172668
# 13    -4234.305377              -0.000195               -1.212227
# 14    -7594.224752              -0.000462               -3.064430
# 15    -5105.112753              -0.000423               -1.052331
# 16    -4673.679591              -0.000149               -2.031538
# 17    -5132.792560              -0.000143               -3.190733
# 18   -12882.255185              -0.000764               -5.118031
# 19    -6357.896125              -0.000288               -2.881453
# 20    -7907.396193              -0.000359               -2.864604
# 21     -301.262190              -0.000308               -0.875867
# 22     1089.991739              -0.000337               -1.086570
# 23     4860.685348              -0.000145                0.894396
# 24    -3034.789248              -0.000199               -1.825304
# 25     -357.043687              -0.000317               -1.653900
# 26      966.944166              -0.000197               -1.383193
# 27    -6352.704264              -0.000624               -5.312960
# 28    -7347.581799              -0.000455               -3.488776
# 29   -11515.393874              -0.000534               -3.491657
#
#     non-renewable energy  net present value      comfort  energy saving
# 0          -81925.573736       -2741.618977 -4237.027369      59.392392
# 1          -38166.058327       -2970.509002 -3648.991571      65.226139
# 2          -93465.177775       -2821.386707 -4118.685570      64.166336
# 3          -12566.067454       -3044.511948 -3579.999992      68.050259
# 4          -89790.964254       -2770.081173 -4284.187502      62.714946
# 5         -140355.455654       -2970.700679 -3667.488634      66.746166
# 6          -13505.580535       -2927.947576 -3841.442706      65.505956
# 7          -65358.325571       -2909.666193 -3957.641118      66.094811
# 8          -41303.616071       -3093.731228 -3339.382926      66.681678
# 9         -102101.004857       -2901.868377 -3898.869891      65.289344
# 10          29855.583994       -2906.457568 -3871.203369      64.070528
# 11         -71841.109262       -2978.496521 -3648.520451      65.293590
# 12          23960.711047       -3010.067564 -3655.014108      67.109409
# 13         -53504.571317       -2917.374211 -3932.746582      65.372019
# 14         -88666.942311       -2838.596066 -3933.248258      61.831389
# 15         -45860.186088       -2849.847650 -3961.128011      61.871577
# 16         -18295.577421       -2806.515207 -4173.923402      63.116289
# 17         -43451.009970       -2812.638843 -4105.828166      63.332997
# 18        -163835.036401       -2862.241252 -3930.358342      63.507269
# 19         -44592.659093       -2873.541074 -3906.158589      64.020977
# 20         -89686.699048       -2997.273222 -3532.167128      64.775688
# 21         -50740.661801       -2992.106503 -3679.612266      65.902124
# 22         -57001.032518       -3029.272481 -3522.929742      66.064876
# 23          -9570.981085       -3151.635204 -3227.712375      68.809846
# 24         -49449.759001       -2957.668746 -3702.968053      64.538879
# 25         -72980.922004       -3028.319449 -3573.024313      68.011675
# 26         -31643.405727       -2945.121432 -3729.098340      64.197993
# 27        -177549.353882       -3050.280682 -3447.662636      68.304047
# 28        -105969.318264       -2873.114656 -3927.226372      64.543711
# 29        -105759.563877       -2753.353054 -4255.682346      61.184279

# %%
original_data.data.corr().values
# Out:
# array([[ 1.        ,  0.79748066,  0.89426404,  0.86189596, -0.45745294,
#          0.29110944,  0.47995826],
#        [ 0.79748066,  1.        ,  0.73738926,  0.91838349, -0.2731839 ,
#          0.09548268,  0.37359984],
#        [ 0.89426404,  0.73738926,  1.        ,  0.87964715, -0.30985155,
#          0.14386418,  0.29346868],
#        [ 0.86189596,  0.91838349,  0.87964715,  1.        , -0.12992345,
#         -0.0349513 ,  0.15759314],
#        [-0.45745294, -0.2731839 , -0.30985155, -0.12992345,  1.        ,
#         -0.96709857, -0.90526542],
#        [ 0.29110944,  0.09548268,  0.14386418, -0.0349513 , -0.96709857,
#          1.        ,  0.79509745],
#        [ 0.47995826,  0.37359984,  0.29346868,  0.15759314, -0.90526542,
#          0.79509745,  1.        ]])

# %%
synthethic_dataset.data.corr().values
# Out:
# array([[ 1.        ,  0.67399851,  0.86679898,  0.74519444, -0.67533569,
#          0.58988646,  0.60308752],
#        [ 0.67399851,  1.        ,  0.62996758,  0.88646261, -0.31980643,
#          0.23133746,  0.3481021 ],
#        [ 0.86679898,  0.62996758,  1.        ,  0.83658043, -0.45677784,
#          0.380666  ,  0.29508414],
#        [ 0.74519444,  0.88646261,  0.83658043,  1.        , -0.20899415,
#          0.13826234,  0.12130714],
#        [-0.67533569, -0.31980643, -0.45677784, -0.20899415,  1.        ,
#         -0.98079315, -0.89449959],
#        [ 0.58988646,  0.23133746,  0.380666  ,  0.13826234, -0.98079315,
#          1.        ,  0.81598326],
#        [ 0.60308752,  0.3481021 ,  0.29508414,  0.12130714, -0.89449959,
#          0.81598326,  1.        ]])
